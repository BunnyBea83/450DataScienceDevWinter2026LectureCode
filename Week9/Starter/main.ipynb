# %% [markdown]
# # Visuals and telling stories with our data
# ## Presentation
# Today things will be a bit diffrent for our typicall presentation section.
# - Step 1. As a group find an choose a dataset. (Try looking for a pre-cleaned dataset to save time, on Kaggle when you search for a Dataset, click on filter and select "Clean data")
# - Step 2. Look through the data and come up with analytical questions
# - Step 3. Discuss with group and pick two questions to answer with plots
# - Step 4. Mob program the plots out on one persons computer
# - Step 5. Pick one plot you want to present at the end to the session
# - Step 6. Screenshot your graphs and submit on Canvas.

# %%
# !pip install pandas numpy seaborn matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\britt\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\britt\anaconda3\lib\site-packages (2.1.3)
# Requirement already satisfied: seaborn in c:\users\britt\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\britt\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\britt\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\britt\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\britt\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\britt\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\britt\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\britt\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\britt\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\britt\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\britt\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\britt\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\britt\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("ODF_Fire_Data.csv")

# %%
df.describe(include="all")
# Out:
#                Serial FireCategory     FireYear   Area      DistrictName  \
# count    23490.000000        23490  23490.00000  23490             23490
# unique            NaN            1          NaN      3                14
# top               NaN         STAT          NaN    SOA  Southwest Oregon
# freq              NaN        23490          NaN  12125              5975
# mean     90425.933461          NaN   2010.80132    NaN               NaN
# std      20901.016028          NaN      6.73508    NaN               NaN
# min      57485.000000          NaN   2000.00000    NaN               NaN
# 25%      72508.500000          NaN   2005.00000    NaN               NaN
# 50%      88340.000000          NaN   2011.00000    NaN               NaN
# 75%     107432.500000          NaN   2017.00000    NaN               NaN
# max     134021.000000          NaN   2022.00000    NaN               NaN
#
#            UnitName FullFireNumber    FireName Size_class  EstTotalAcres  ...  \
# count         23490          23490       23490      23490   23411.000000  ...
# unique           31          23335       19637          7            NaN  ...
# top     Grants Pass   07-952047-08  Mill Creek          A            NaN  ...
# freq           3072              2          33      17013            NaN  ...
# mean            NaN            NaN         NaN        NaN     270.802503  ...
# std             NaN            NaN         NaN        NaN    6816.736966  ...
# min             NaN            NaN         NaN        NaN       0.000000  ...
# 25%             NaN            NaN         NaN        NaN       0.010000  ...
# 50%             NaN            NaN         NaN        NaN       0.100000  ...
# 75%             NaN            NaN         NaN        NaN       0.500000  ...
# max             NaN            NaN         NaN        NaN  499945.000000  ...
#
#              Industrial_Restriction            Ign_DateTime  \
# count                         23401                   23396
# unique                            7                   20257
# top     Does Not Apply - Eastern OR  07/15/2018 09:00:00 AM
# freq                           6562                      92
# mean                            NaN                     NaN
# std                             NaN                     NaN
# min                             NaN                     NaN
# 25%                             NaN                     NaN
# 50%                             NaN                     NaN
# 75%                             NaN                     NaN
# max                             NaN                     NaN
#
#                 ReportDateTime       Discover_DateTime  \
# count                    23490                   23396
# unique                   22822                   22504
# top     08/17/2022 05:00:00 PM  08/17/2022 05:00:00 PM
# freq                        18                      19
# mean                       NaN                     NaN
# std                        NaN                     NaN
# min                        NaN                     NaN
# 25%                        NaN                     NaN
# 50%                        NaN                     NaN
# 75%                        NaN                     NaN
# max                        NaN                     NaN
#
#               Control_DateTime            CreationDate  \
# count                    23395                   23487
# unique                   22304                   11005
# top     12/31/2013 12:00:00 PM  08/19/2008 12:00:00 AM
# freq                        20                      67
# mean                       NaN                     NaN
# std                        NaN                     NaN
# min                        NaN                     NaN
# 25%                        NaN                     NaN
# 50%                        NaN                     NaN
# 75%                        NaN                     NaN
# max                        NaN                     NaN
#
#                   ModifiedDate  DistrictCode      UnitCode DistFireNumber
# count                    23490  23490.000000  23490.000000          23490
# unique                   22865           NaN           NaN           1009
# top     10/26/2001 10:20:00 AM           NaN           NaN            018
# freq                        12           NaN           NaN            257
# mean                       NaN     77.754662    779.371052            NaN
# std                        NaN     14.618857    146.534574            NaN
# min                        NaN     51.000000    511.000000            NaN
# 25%                        NaN     71.000000    711.000000            NaN
# 50%                        NaN     73.000000    732.000000            NaN
# 75%                        NaN     95.000000    954.000000            NaN
# max                        NaN     99.000000    991.000000            NaN
#
# [11 rows x 38 columns]

# %%
df_columns_renamed = df.rename(columns={
     
    "Serial": "serial_id",
    "FireCategory": "fire_category",
    "FireYear": "fire_year",
    "Area": "area_name",
    "DistrictName": "district_name",
    "UnitName": "unit_name",
    "FullFireNumber": "full_fire_number",
    "FireName": "fire_name",
    "EstTotalAcres": "estimated_total_acres",
    "ReportDateTime": "report_datetime",
    "CreationDate": "created_at",
    "ModifiedDate": "modified_at",
    "DistrictCode": "district_code",
    "UnitCode": "unit_code",
    "DistFireNumber": "district_fire_number"
})

df.columns = df_columns_renamed.columns.str.lstrip().str.rstrip().str.replace(' ', '_').str.lower()

# %%
df.head()
# Out:
#    serial_id fire_category  fire_year area_name         district_name  \
# 0     102649          STAT       2015       EOA          Klamath-Lake
# 1     131239          STAT       2022       EOA  Walker Range - WRFPA
# 2      58256          STAT       2000       EOA        Central Oregon
# 3      59312          STAT       2000       EOA      Northeast Oregon
# 4      61657          STAT       2001       SOA      Southwest Oregon
#
#      unit_name full_fire_number      fire_name size_class  \
# 0      Klamath     15-981082-16       Bass 497          B
# 1     Crescent     22-991220-23       Hay Fire          A
# 2     John Day     00-952011-01   Slick Ear #2          B
# 3    La Grande     00-971024-01        Woodley          C
# 4  Grants Pass     01-712133-02  QUEENS BRANCH          A
#
#    estimated_total_acres  ...       industrial_restriction  \
# 0                   3.20  ...  Does Not Apply - Eastern OR
# 1                    NaN  ...                          NaN
# 2                   0.75  ...  Does Not Apply - Eastern OR
# 3                  80.00  ...  Does Not Apply - Eastern OR
# 4                   0.10  ...    Lvl 3 Restricted Shutdown
#
#              ign_datetime         report_datetime       discover_datetime  \
# 0  09/02/2015 05:00:00 PM  09/02/2015 05:05:00 PM  09/02/2015 05:00:00 PM
# 1                     NaN  08/16/2022 06:56:00 PM                     NaN
# 2  07/18/2000 07:00:00 PM  07/19/2000 01:20:00 PM  07/19/2000 01:15:00 PM
# 3  08/24/2000 05:30:00 AM  08/24/2000 01:07:00 PM  08/24/2000 01:07:00 PM
# 4  08/10/2001 05:40:00 PM  08/10/2001 05:47:00 PM  08/10/2001 05:45:00 PM
#
#          control_datetime              created_at             modified_at  \
# 0  09/02/2015 11:00:00 PM  09/05/2015 12:00:00 AM  10/13/2015 08:39:00 AM
# 1                     NaN  08/18/2022 12:00:00 AM  08/18/2022 09:11:00 AM
# 2  07/20/2000 12:50:00 AM  07/20/2000 09:13:00 AM  11/14/2000 09:16:00 AM
# 3  09/01/2000 09:30:00 PM  08/29/2000 03:59:00 PM  12/21/2000 04:22:00 PM
# 4  08/10/2001 06:30:00 PM  08/10/2001 06:42:00 PM  08/17/2001 11:45:00 AM
#
#    district_code unit_code district_fire_number
# 0             98       981                  082
# 1             99       991                  220
# 2             95       952                  011
# 3             97       971                  024
# 4             71       712                  133
#
# [5 rows x 38 columns]

# %%
df.isna().sum().sum()
# Out:
# np.int64(16012)

# %%
# Fill NaN
df["specificcause"] = df["specificcause"].fillna("unknown")
df["causeby"] = df["causeby"].fillna("unknown")

# %%
# Drop NaN
df = df.dropna()
print(df.shape)
# Out:
# (9170, 38)

# %%
print(df.isna().sum().sort_values())
# Out:
# serial_id                 0
# fire_category             0
# fire_year                 0
# area_name                 0
# district_name             0
# unit_name                 0
# full_fire_number          0
# fire_name                 0
# size_class                0
# estimated_total_acres     0
# protected_acres           0
# humanorlightning          0
# causeby                   0
# generalcause              0
# specificcause             0
# cause_comments            0
# lat_dd                    0
# long_dd                   0
# latlongdd                 0
# fo_landowntype            0
# twn                       0
# rng                       0
# sec                       0
# subdiv                    0
# landmarklocation          0
# county                    0
# regusezone                0
# reguserestriction         0
# industrial_restriction    0
# ign_datetime              0
# report_datetime           0
# discover_datetime         0
# control_datetime          0
# created_at                0
# modified_at               0
# district_code             0
# unit_code                 0
# district_fire_number      0
# dtype: int64

# %% [markdown]
# ## Updating Dates
#
# You must convert your dates from strings into datetime objects.
# This allows you to use built-in date methods and perform time-based calculations.

# %%
df["ign_datetime"].head(20)
df["discover_datetime"].head(20)
df["control_datetime"].head(20)
df["report_datetime"].head(20)
# Out:
# 15     10/26/2008 12:01:00 PM
# 21     08/17/2009 11:52:00 AM
# 22     07/15/2009 05:30:00 AM
# 40     09/25/2016 11:23:00 AM
# 54     08/03/2019 04:35:00 PM
# 57     04/29/2020 05:52:00 PM
# 77     08/05/2007 01:54:00 PM
# 79     09/01/2007 08:38:00 PM
# 95     04/24/2009 08:45:00 PM
# 98     10/04/2007 12:16:00 PM
# 103    08/15/2008 02:55:00 PM
# 114    08/24/2009 04:16:00 PM
# 120    08/06/2008 09:25:00 AM
# 124    08/01/2009 06:08:00 PM
# 133    10/11/2008 11:53:00 AM
# 157    06/03/2009 12:49:00 PM
# 166    09/04/2008 07:01:00 PM
# 168    08/08/2008 08:54:00 AM
# 176    06/28/2009 02:06:00 PM
# 186    09/14/2007 03:00:00 PM
# Name: report_datetime, dtype: object

# %%
date_columns = [
    "ign_datetime",
    "discover_datetime",
    "control_datetime",
    "report_datetime"
]

for col in date_columns:
    df[col] = pd.to_datetime(
        df[col],
        format="%m/%d/%Y %I:%M:%S %p",
        errors="coerce"
    )

df[date_columns].dtypes
# Out:
# ign_datetime         datetime64[ns]
# discover_datetime    datetime64[ns]
# control_datetime     datetime64[ns]
# report_datetime      datetime64[ns]
# dtype: object

# %%
for item in df.columns:
  print(item)
# Out:
# serial_id
# fire_category
# fire_year
# area_name
# district_name
# unit_name
# full_fire_number
# fire_name
# size_class
# estimated_total_acres
# protected_acres
# humanorlightning
# causeby
# generalcause
# specificcause
# cause_comments
# lat_dd
# long_dd
# latlongdd
# fo_landowntype
# twn
# rng
# sec
# subdiv
# landmarklocation
# county
# regusezone
# reguserestriction
# industrial_restriction
# ign_datetime
# report_datetime
# discover_datetime
# control_datetime
# created_at
# modified_at
# district_code
# unit_code
# district_fire_number

# %% [markdown]
# ## What kinds of information can we gain from this data?

# %%
df["ign_datetime"].notna().sum()
df["ign_datetime"].head()
# Out:
# 15   2008-10-26 11:45:00
# 21   2009-08-17 11:48:00
# 22   2009-07-12 19:00:00
# 40   2016-09-24 23:59:00
# 54   2019-08-03 16:30:00
# Name: ign_datetime, dtype: datetime64[ns]

# %%
df = df.dropna(subset=["ign_datetime"])

# %%
df["month"] = df["ign_datetime"].dt.month
df["month"]
# Out:
# 15       10
# 21        8
# 22        7
# 40        9
# 54        8
#          ..
# 23481     3
# 23486     9
# 23487     6
# 23488     8
# 23489     8
# Name: month, Length: 9170, dtype: int32

# %%
fires_per_month = df.groupby("month").size()
fires_per_month
fires_per_month
# Out:
# month
# 1       27
# 2       53
# 3      112
# 4      340
# 5      649
# 6     1194
# 7     2229
# 8     2406
# 9     1368
# 10     633
# 11     135
# 12      24
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
fires_per_month.plot(kind="bar")
plt.title("Number of Fires per Month")
plt.xlabel("Month")
plt.ylabel("Number of Fires")
plt.show()

# %%
import calendar
import matplotlib.colors as colors

fires_per_month.index = [calendar.month_name[i] for i in fires_per_month.index]
fires_per_month
# Out:
# January        27
# February       53
# March         112
# April         340
# May           649
# June         1194
# July         2229
# August       2406
# September    1368
# October       633
# November      135
# December       24
# dtype: int64

# %%
# Add colors
color_map = plt.get_cmap("YlOrRd")
normalized_months = colors.Normalize(
    vmin = fires_per_month.min(),
    vmax = fires_per_month.max()
)

bars = color_map(normalized_months(fires_per_month.values))
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot()
ax.set_facecolor("dimgray")
ax.bar(fires_per_month.index, fires_per_month.values, color=bars)
ax.set_title("Number of Fires per Month", color="darkred")
ax.set_xlabel("Month", color="black")
ax.set_ylabel("Number of Fires", color="darkred")
#rename the x axis labels
for label in ax.get_xticklabels():
    label.set_rotation(45)
    label.set_ha("right")
plt.show()

# %% [markdown]
# ## What Makes a Good Visualization
#
# ### 1. Select the Right Chart
# - **Bar charts:** Great for categorical data.
# - **Line charts:** Useful for showing trends over time.
# - **Scatter plots:** Show relationships between two variables.
# - **Histograms:** Show the frequency or distribution of data.
# - **Box plots:** Summarize the distribution of data and help identify outliers.
# - **Area charts:** Show changes in quantities over time and emphasize magnitude.
#
# ### 2. Simplify and Declutter for Effective Visualization
# - Less is usually better. Can someone understand your chart in under 15 seconds?
# - Remove gridlines if they do not help with comprehension.
# - Avoid unnecessary decorations that do not support your message.
# - Use clean, concise labels without overcrowding the chart.
# - Clean up axes by removing excessive labels or ticks.
#
# ### 3. Use Color Carefully
# - Color can highlight important points, but too much color can be confusing.
# - Use color to highlight key data.
# - Use consistent colors to group related items and help viewers spot trends.
#
# ### 4. Tell a Story
# - Use titles, labels, and annotations to provide context.
# - Highlight key insights to make the data easier to understand.

# %%
df['month'] = df['ing_datetime'].dt.month
df['month']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\britt\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ing_datetime'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df['month'] = df['ing_datetime'].dt.month
#       2 df['month']
#
# File c:\Users\britt\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\britt\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'ing_datetime'

# %%
plt.figure(figsize=(10, 10))

# %% [markdown]
# # Your Turn:
# - Step 1. As a group find an choose a new dataset.
# - Step 2. Look through the data and come up with analytical questions
# - Step 3. Discuss with group and pick two questions to answer with plots
# - Step 4. Mob program the plots out on one persons computer
# - Step 5. Pick one plot you want to present at the end to the session
#
# Work with your group to mob program the plots and be prepared to share them with the class.
